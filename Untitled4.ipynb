# %% [markdown]
# <a href="https://colab.research.google.com/github/SANJAIKANTH46/Task-1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Program to find the largest of three numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest is:", a)

elif b > c:
    print("Largest is:", b)

else:
    print("Largest is:", c)
# Out:
# Enter first number: 3
# Enter second number: 5
# Enter third number: 1
# Largest is: 5

# %%
# 2. Program to check leap year

year = int(input("Enter year: "))

if year % 4 == 0:
    print(year, "is a leap year.")

else:
    print(year, "is not a leap year.")
# Out:
# Enter year: 2005
# 2005 is not a leap year.

# %%
# 3. Program to check vowel or consonant

ch = input("Enter a letter: ").lower()

if ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u':
    print("Vowel")

else:
    print("Consonant")
# Out:
# Enter a letter: a
# Vowel

# %%
# 4. Program to check divisibility by 5 and 11

n = int(input("Enter number: "))

if n % 5 == 0 and n % 11 == 0:
    print(n, "is divisible by both 5 and 11")

else:
    print(n, "is not divisible by both 5 and 11")
# Out:
# Enter number: 6
# 6 is not divisible by both 5 and 11

# %%
# 5. Sum of first N natural numbers using while loop

n = int(input("Enter value of n: "))

sum = 0
i = 1

while i <= n:
    sum = sum + i
    i = i + 1

print("Sum =", sum)
# Out:
# Enter value of n: 30
# Sum = 465

# %%
# 6. Multiplication table using while loop

n = int(input("Enter a number: "))

i = 1

while i <= 10:
    print(n, "x", i, "=", n * i)
    i = i + 1
# Out:
# Enter a number: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
# 7. Pyramid pattern

rows = 5

for i in range(1, rows + 1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
# 8. Number pattern

for i in range(1, 6):
    for j in range(1, i + 1):
        print(j, end="")

    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
